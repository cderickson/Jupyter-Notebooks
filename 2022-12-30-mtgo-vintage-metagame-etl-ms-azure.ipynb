# %%
import pandas as pd
import numpy as np
import csv
from datetime import datetime
from datetime import date
import calendar
import requests
import pyodbc
import warnings
warnings.filterwarnings('ignore')

# %%
def get_login():
	server = ''
	db = ''
	uid = ''
	passwd = ''
	with open("azure.txt") as f:
		lines = f.read().split("\n")
		for i in lines:
			if i.split("=")[0] == "server":
				server = i.split("=")[1]
			if i.split("=")[0] == "db":
				db = i.split("=")[1]
			if i.split("=")[0] == "uid":
				uid = i.split("=")[1]
			if i.split("=")[0] == "passwd":
				passwd = i.split("=")[1]	
	return (server, db, uid, passwd)

# %%
def get_sheet(spreadsheetID, sheetID, create_date, save):
	url = f"https://docs.google.com/spreadsheets/d/{spreadsheetID}/gviz/tq?tqx=out:csv&gid={sheetID}"
	res = requests.get(url)
	if save == True:
		with open(f"vintage-metagame-rawdata-{create_date}.csv", "wb") as f:
			f.write(res.content)
	return pd.read_csv(url)

# %%
def clean_merged_data(create_date, save, raw):
	vintage = raw[raw.columns[:11]]
	vintage.columns = ['rank','player','wins','losses','byes','arch','subarch','deck','details','date','event_type']

	# Replace NA values in 'byes' column with 0.
	vintage.byes = vintage.byes.fillna(0)
	vintage.byes = vintage.byes.astype("int")

	# Propagate 'event_type' data to each record.
	vintage["event_type"].replace({"Showcase Qualifier": "Showcase_Qualifier"}, inplace=True)

	event_type = vintage.event_type.tolist()
	for index,i in enumerate(event_type):
		if isinstance(i, str):
			new = i
		else:
			event_type[index] = new
	
	vintage["event_type"] = event_type

	event_cnt = 1
	date_last = ''
	etype_last = ''
	event_id = []
	dates_new = []
	for index, row in vintage.iterrows():
		month = row['date'].split("/")[0].zfill(2)
		day = row['date'].split("/")[1].zfill(2)
		year = row['date'].split("/")[2]
		if row['rank'] == 1:
			if (f'20{year}-{month}-{day}' == date_last) and (row['event_type'] == etype_last):
				event_cnt += 1
			if (f'20{year}-{month}-{day}' != date_last) or (row['event_type'] != etype_last):
				event_cnt = 1
		etype = row['event_type']
		event_id.append(f'20{year}-{month}-{day}-{etype}-{event_cnt}')
		dates_new.append(f'20{year}-{month}-{day}')
		date_last = f'20{year}-{month}-{day}'
		etype_last = row['event_type']
	vintage["event_id"] = event_id

	# Create a second table called Events. Remove duplicate records such that each row represents a unique event.
	events = pd.DataFrame({"event_id" : event_id, "event_type" : event_type, "date" : dates_new})
	events = events.groupby(["event_id"], as_index=False)["event_type", "date"].last()

	# Add 'entries' column to Events table to represents number of players in each event.
	players = vintage.groupby(["event_id"], as_index=False)["rank"].max()

	events = events.merge(players, on="event_id")
	events.rename(columns={"rank" : "entries", "date" : "event_date"}, inplace=True)

	# Add 'day_of_week' column to Events table.
	events["day_of_week"] = events["event_date"].apply(lambda x: calendar.day_name[datetime.strptime(x, "%Y-%m-%d").weekday()])

	# Drop 'details' column. Drop 'date' and 'event_type' columns that are now in the Events table.
	vintage.drop(["details"], axis=1, inplace=True)
	vintage.drop(["date"], axis=1, inplace=True)
	vintage.drop(["event_type"], axis=1, inplace=True)

	# Rename 'rank' column to 'finish'.
	vintage.rename(columns={"rank" : "finish"}, inplace=True)

	# Replace commas and quotes because it breaks importing with SQL commands.
	vintage["arch"] = vintage["arch"].apply(lambda x: str(x).replace(",", ""))
	vintage["subarch"] = vintage["subarch"].apply(lambda x: str(x).replace(",", ""))
	vintage["deck"] = vintage["deck"].apply(lambda x: str(x).replace(",", ""))
	
	vintage['arch'] = vintage['arch'].apply(lambda x: x.replace("'", ''))
	vintage['subarch'] = vintage['subarch'].apply(lambda x: x.replace("'", ''))
	vintage['deck'] = vintage['deck'].apply(lambda x: x.replace("'", ''))
	
	# Save and export to CSV.
	if save == True:
		vintage.to_csv(f"vintage-results-{create_date}.csv", index=False)
		events.to_csv(f"vintage-events-{create_date}.csv", index=False)
	return (vintage, events)

# %%
create_date = date.today().strftime("%Y-%m-%d")
df = get_sheet("1wxR3iYna86qrdViwHjUPzHuw6bCNeMLb72M25hpUHYk", "1693401931", create_date, save=False)
vintage, events = clean_merged_data(create_date=create_date, save=False, raw=df)

# %%
server, db, uid, passwd = get_login()

# Connect to the database
conn_str = 'DRIVER={SQL Server};SERVER=tcp:' + f'{server};PORT=1433;DATABASE={db};UID={uid};PWD={passwd}'
print(conn_str)
conn = pyodbc.connect(conn_str)
cursor = conn.cursor()

events_added = 0
events_updated = 0
results_added = 0
results_updated = 0
for index, row in events.iterrows():
    values = tuple(row.tolist())
    event_id = row['event_id']
    event_type = row['event_type']
    event_date = row['event_date']
    entries = row['entries']
    day_of_week = row['day_of_week']
    try:
        cursor.execute('INSERT INTO vintage_events (event_id, event_type, event_date, entries, day_of_week) VALUES (?, ?, ?, ?, ?)', values)
        events_added += 1
    except:
        sql = f"UPDATE vintage_events SET event_type = '{event_type}', event_date = '{event_date}', entries = {entries}, day_of_week = '{day_of_week}' WHERE event_id = '{event_id}'"
        cursor.execute(sql)
        events_updated += 1

for index, row in vintage.iterrows():
    values = tuple(row.tolist())
    finish = row['finish']
    player = row['player']
    wins = row['wins']
    losses = row['losses']
    byes = row['byes']
    arch = row['arch']
    subarch = row['subarch']
    deck = row['deck']
    event_id = row['event_id']
    try:
        cursor.execute('INSERT INTO vintage_results (finish, player, wins, losses, byes, arch, subarch, deck, event_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)', values)
        results_added += 1
    except:
        sql = f"UPDATE vintage_results SET player = '{player}', wins = {wins}, losses = {losses}, byes = {byes}, arch = '{arch}', subarch = '{subarch}', deck = '{deck}' WHERE finish = {finish} AND event_id = '{event_id}'"
        print(sql)
        cursor.execute(sql)
        results_updated += 1

print(f'events added: {events_added}, skipped: {events_updated}')
print(f'results added: {results_added}, skipped: {results_updated}')

# Commit the transaction and close the connection
conn.commit()
conn.close()
# Out:
# DRIVER={SQL Server};SERVER=tcp:sundodger.database.windows.net;PORT=1433;DATABASE=sundodgerdb;UID=chriserickson;PWD=Erickson10
# UPDATE vintage_results SET player = 'sixmp', wins = 8, losses = 1, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'nan' WHERE finish = 1 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'JOANANTON', wins = 7, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'Esper Saga PO' WHERE finish = 2 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Vertyx_', wins = 7, losses = 1, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'nan' WHERE finish = 3 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'yoshiwata', wins = 6, losses = 2, byes = 0, arch = 'DRS', subarch = '4c DRS Walkers', deck = 'nan' WHERE finish = 4 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'medvedev', wins = 5, losses = 2, byes = 0, arch = 'Combo', subarch = 'Oops All Spells', deck = 'nan' WHERE finish = 5 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'discoverN', wins = 5, losses = 2, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'nan' WHERE finish = 6 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Cherryxman', wins = 4, losses = 3, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel' WHERE finish = 7 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'WhiTe TsaR', wins = 4, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Init' WHERE finish = 8 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Bryzem1', wins = 4, losses = 2, byes = 0, arch = 'DRS', subarch = '4c DRS Walkers', deck = 'nan' WHERE finish = 9 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'sandydogmtg', wins = 4, losses = 2, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel' WHERE finish = 10 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'excel0679', wins = 4, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 11 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'boulderelf', wins = 4, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'Gaak' WHERE finish = 12 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Rooney56', wins = 4, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'Jeskai PO' WHERE finish = 13 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'IdraftTheBeatz', wins = 4, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'nan' WHERE finish = 14 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Musasabi', wins = 4, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Init' WHERE finish = 15 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'vwxyza648204', wins = 4, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'Gaak' WHERE finish = 16 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Darkmattergun', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Init' WHERE finish = 17 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'ecobaronen', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Init' WHERE finish = 18 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'ZYURYO', wins = 3, losses = 3, byes = 1, arch = 'Aggro', subarch = 'Mono White', deck = 'Init' WHERE finish = 19 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Wizard_2002', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Dredge', deck = 'nan' WHERE finish = 20 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'CodeProvider', wins = 3, losses = 3, byes = 0, arch = 'Other', subarch = 'Other', deck = 'Magus Deck' WHERE finish = 21 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Sahakvic', wins = 3, losses = 3, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'nan' WHERE finish = 22 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'duke12', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'nan' WHERE finish = 23 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'ger5559', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Dredge', deck = 'nan' WHERE finish = 24 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'zwischenzug', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'Squee with Griefs' WHERE finish = 25 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'kthanakit26', wins = 3, losses = 3, byes = 0, arch = 'Shops', subarch = 'Prison Shops', deck = 'nan' WHERE finish = 26 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'SingPanMan', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'nan' WHERE finish = 27 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Mogged', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Other Blue Tempo', deck = 'Merfolk' WHERE finish = 28 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'KingHairy', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Init' WHERE finish = 29 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'desolutionist', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Tendrils' WHERE finish = 30 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Breckoroni', wins = 2, losses = 4, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel' WHERE finish = 31 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = '_Shatun_', wins = 2, losses = 4, byes = 1, arch = 'Aggro', subarch = 'Mono White', deck = 'nan' WHERE finish = 32 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'hopeof130', wins = 2, losses = 4, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'nan' WHERE finish = 33 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = '42crookedsporks', wins = 2, losses = 4, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Goblins' WHERE finish = 34 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Killah_SUV', wins = 2, losses = 1, byes = 0, arch = 'Combo', subarch = 'Oops All Spells', deck = 'nan' WHERE finish = 35 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'unluckymonkey', wins = 2, losses = 4, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'nan' WHERE finish = 36 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Wesal', wins = 2, losses = 4, byes = 0, arch = 'Aggro', subarch = 'Other Aggro', deck = 'GW' WHERE finish = 37 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'yPrincipe', wins = 2, losses = 4, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'nan' WHERE finish = 38 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'tyerube1618', wins = 2, losses = 4, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel' WHERE finish = 39 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = '_Gerwaz', wins = 1, losses = 5, byes = 1, arch = 'Aggro', subarch = 'Mono White', deck = 'nan' WHERE finish = 40 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Minest110', wins = 1, losses = 3, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'nan' WHERE finish = 41 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'TunnelGaan', wins = 1, losses = 5, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'nan' WHERE finish = 42 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'funkybrewster', wins = 1, losses = 4, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'nan' WHERE finish = 43 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Slasher21', wins = 0, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Other Blue Tempo', deck = 'UR Sprite' WHERE finish = 44 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'mei0024', wins = 0, losses = 3, byes = 0, arch = 'Blue Control', subarch = 'Other Blue Control', deck = 'nan' WHERE finish = 45 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Tsubasa_Cat', wins = 0, losses = 2, byes = 0, arch = 'Shops', subarch = 'Prison Shops', deck = 'nan' WHERE finish = 46 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Crazydiamond513', wins = 0, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'UW' WHERE finish = 47 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'thepowernine', wins = 0, losses = 3, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel' WHERE finish = 48 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'Koala40', wins = 0, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Init' WHERE finish = 49 AND event_id = '2022-12-25-Challenge-1'
# UPDATE vintage_results SET player = 'sixmp', wins = 8, losses = 1, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 1 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'tajoordan', wins = 7, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'Cradlevine' WHERE finish = 2 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Koala40', wins = 6, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 3 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Bryzem1', wins = 5, losses = 3, byes = 0, arch = 'DRS', subarch = '4c DRS Walkers', deck = '4c Walkers' WHERE finish = 4 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'JUJUBEAN__2004', wins = 6, losses = 1, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'SqueeVine' WHERE finish = 5 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Wizard_2002', wins = 5, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Dredge', deck = 'Dredge' WHERE finish = 6 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'teichou_aisu', wins = 5, losses = 2, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel Shops' WHERE finish = 7 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Vertyx_', wins = 4, losses = 3, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 8 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Condescend', wins = 4, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'Dimir Tinker' WHERE finish = 9 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'SuperCow12653', wins = 4, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 10 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = '42crookedsporks', wins = 4, losses = 2, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Goblins' WHERE finish = 11 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'IdraftTheBeatz', wins = 4, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'Esper Tinker' WHERE finish = 12 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'anexaltedpariah', wins = 4, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'UW PO' WHERE finish = 13 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'WingedHussar', wins = 4, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 14 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'TenArms', wins = 4, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 15 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Butakov', wins = 4, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 16 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Cherryxman', wins = 4, losses = 2, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel Shops' WHERE finish = 17 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'HermonHero', wins = 4, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 18 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'HouseOfManaMTG', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'SqueeVine' WHERE finish = 19 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'SenpaiBlank', wins = 3, losses = 3, byes = 1, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 20 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'chase21', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Izzet Blecher' WHERE finish = 21 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'desolutionist', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Dimir Storm' WHERE finish = 22 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'EricSlashGreg', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 23 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'schiaveto', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'SqueeVine' WHERE finish = 24 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'sandydogmtg', wins = 3, losses = 3, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel Shops' WHERE finish = 25 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'SanPop', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 26 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'duke12', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'Grixis Lurrus' WHERE finish = 27 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Alpha_Omega', wins = 3, losses = 3, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 28 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Dreddybajs', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 29 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'D00mwake', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 30 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Karolmo', wins = 3, losses = 3, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'Aggro Shops' WHERE finish = 31 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'kasa', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Dredge', deck = 'Dredge' WHERE finish = 32 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'MTGMack', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 33 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'TunnelGaan', wins = 2, losses = 4, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'Esper Tinker' WHERE finish = 34 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'discoverN', wins = 2, losses = 4, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 35 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Kummins11', wins = 2, losses = 4, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 36 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'RYO410', wins = 2, losses = 4, byes = 0, arch = 'Oath', subarch = 'Oath', deck = 'RUG Oath' WHERE finish = 37 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Wesal', wins = 2, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Other Aggro', deck = 'GW Lumi' WHERE finish = 38 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'kauffj', wins = 2, losses = 4, byes = 0, arch = 'Other', subarch = 'Other', deck = '4c Lurrus' WHERE finish = 39 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'yPrincipe', wins = 2, losses = 4, byes = 1, arch = 'Shops', subarch = 'Aggro Shops', deck = 'Aggro Shops' WHERE finish = 40 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'MadMaxErnst', wins = 1, losses = 4, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Jeskai' WHERE finish = 41 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'therealkinda', wins = 1, losses = 5, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'Dimir Tinker' WHERE finish = 42 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'GontiLordofStuff', wins = 1, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'Cradle Vine' WHERE finish = 43 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'mogged', wins = 1, losses = 4, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'Squee Vine' WHERE finish = 44 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'medvedev', wins = 1, losses = 4, byes = 0, arch = 'Combo', subarch = 'Oops All Spells', deck = 'OOps' WHERE finish = 45 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Minest110', wins = 1, losses = 3, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Non Lurrus' WHERE finish = 46 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Delve3', wins = 1, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 47 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'lucadaky', wins = 1, losses = 4, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'Esper Tinker' WHERE finish = 48 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'albertoSD', wins = 1, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 49 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Karatedom', wins = 0, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W' WHERE finish = 50 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Nammersquats', wins = 0, losses = 2, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 51 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'Eonwe7', wins = 0, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'UB Tinker' WHERE finish = 52 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'scalo94', wins = 0, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'Esper Tinker' WHERE finish = 53 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'quinniac', wins = 0, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = '3 Island PO' WHERE finish = 54 AND event_id = '2022-12-24-Challenge-1'
# UPDATE vintage_results SET player = 'bless_von', wins = 9, losses = 0, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W Initative' WHERE finish = 1 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'TrueHero', wins = 7, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'Esper Tinker' WHERE finish = 2 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Cherryxman', wins = 6, losses = 2, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel Shops' WHERE finish = 3 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'SenpaiBlank', wins = 6, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W Initative' WHERE finish = 4 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'CodeProvider', wins = 5, losses = 2, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Izzet Belcher' WHERE finish = 5 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Zwischenzug', wins = 5, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'SqueeVine' WHERE finish = 6 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'unluckymonkey', wins = 4, losses = 3, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 7 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'discoverN', wins = 4, losses = 3, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 8 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'medvedev', wins = 4, losses = 2, byes = 0, arch = 'Combo', subarch = 'Oops All Spells', deck = 'Oops' WHERE finish = 9 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Mogged', wins = 4, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'SqueeVine' WHERE finish = 10 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Dazai', wins = 4, losses = 2, byes = 0, arch = 'DRS', subarch = '4c DRS Walkers', deck = '4c Walkers' WHERE finish = 11 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'ice_nine_BIGFAN', wins = 4, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W Initative' WHERE finish = 12 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Wesal', wins = 4, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Other Aggro', deck = 'G/W Lumi' WHERE finish = 13 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'MadMaxErnst', wins = 4, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 14 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'TunnelGaan', wins = 4, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'Esper Tinker' WHERE finish = 15 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Slasher21', wins = 4, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W Initative' WHERE finish = 16 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Yamaro', wins = 4, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'Dimir Tinker' WHERE finish = 17 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'scalo94', wins = 4, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'Dimir Tinker' WHERE finish = 18 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Gerwaz', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 19 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'scipios', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'SqueeVine' WHERE finish = 20 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = '416FrowningTable', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W Initative' WHERE finish = 21 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Solidsnake408', wins = 3, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'Esper Po' WHERE finish = 22 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Elfkid', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W Initative' WHERE finish = 23 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'ecobaronen', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W Initative' WHERE finish = 24 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'yPrincipe', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W Initative' WHERE finish = 25 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Money', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Dimir Storm' WHERE finish = 26 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'LeoFa', wins = 3, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'Dimir Tinker' WHERE finish = 27 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Vertyx_', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 28 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'musasabi', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W Initative' WHERE finish = 29 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'dgreen16', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Dredge', deck = 'Dredge' WHERE finish = 30 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'SingPanMan', wins = 3, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Other Blue Tempo', deck = 'Merfolk' WHERE finish = 31 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'vwxyza648204', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Dredge', deck = 'Dredge' WHERE finish = 32 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Sahakvic', wins = 3, losses = 3, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'Aggro Shops' WHERE finish = 33 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Butakov', wins = 2, losses = 4, byes = 0, arch = 'Blue Tinker', subarch = 'Grixis Saga', deck = 'Grixis Tinker Saga' WHERE finish = 34 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'jaredallsop619', wins = 2, losses = 4, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'Dimir Tinker' WHERE finish = 35 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Zubekanov', wins = 2, losses = 4, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 36 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Laessoe', wins = 2, losses = 4, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'SqueeVine' WHERE finish = 37 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Kenzaburo', wins = 2, losses = 4, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 38 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Wyjx', wins = 2, losses = 4, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'SqueeVine' WHERE finish = 39 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'bennybo', wins = 2, losses = 4, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 40 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = '518gpo', wins = 2, losses = 4, byes = 1, arch = 'DRS', subarch = '4c DRS Walkers', deck = '4c Walkers' WHERE finish = 41 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'KingHairy', wins = 1, losses = 2, byes = 1, arch = 'Blue Tinker', subarch = 'Grixis Saga', deck = 'Grixis Tinker Breacher' WHERE finish = 42 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Wizard_2002', wins = 1, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W Initative' WHERE finish = 43 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Nerdkneereape', wins = 1, losses = 4, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono W Initative' WHERE finish = 44 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'trunks132', wins = 1, losses = 2, byes = 1, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'SqueeVine' WHERE finish = 45 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'revenantkioku', wins = 1, losses = 5, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 46 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'ZYURYO', wins = 1, losses = 4, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'Jeskai Tinker Saga' WHERE finish = 47 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Promidnightz', wins = 1, losses = 3, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'Grixis Tinker Breach' WHERE finish = 48 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Clamavus', wins = 0, losses = 2, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'Car Shops' WHERE finish = 49 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'OKMV', wins = 0, losses = 3, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 50 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Breckoroni', wins = 0, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'Esper PO' WHERE finish = 51 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'shir kahn', wins = 0, losses = 4, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 52 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'hakumei1234', wins = 0, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Mono Whie Iniative' WHERE finish = 53 AND event_id = '2022-12-18-Challenge-1'
# UPDATE vintage_results SET player = 'Musasabi', wins = 8, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative' WHERE finish = 1 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'IdraftTheBeatz', wins = 8, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'nan' WHERE finish = 2 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Michelino', wins = 7, losses = 2, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'Grixis Lurrus Breach' WHERE finish = 3 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = '42crookedsporks', wins = 6, losses = 3, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Goblins' WHERE finish = 4 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'dgreen16', wins = 6, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Dredge', deck = 'nan' WHERE finish = 5 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Serjero', wins = 6, losses = 2, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel' WHERE finish = 6 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = '416FrowningTable', wins = 6, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative' WHERE finish = 7 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Money', wins = 5, losses = 3, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Voidwalker Storm' WHERE finish = 8 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'unluckymonkey', wins = 5, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 9 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Condescend', wins = 5, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'UB Sheo' WHERE finish = 10 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'S063', wins = 5, losses = 2, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'Car Shops w. Initiative' WHERE finish = 11 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Jmallan', wins = 5, losses = 2, byes = 0, arch = 'Shops', subarch = 'Prison Shops', deck = 'nan' WHERE finish = 12 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Miharu_Fuyumiya', wins = 5, losses = 2, byes = 0, arch = 'Oath', subarch = 'Oath', deck = 'nan' WHERE finish = 13 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'TheBrogan', wins = 5, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'PitchVine' WHERE finish = 14 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'TrueHero', wins = 4, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'UB Sheo' WHERE finish = 15 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'yPrincipe', wins = 4, losses = 3, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'nan' WHERE finish = 16 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Nammersquats', wins = 4, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative' WHERE finish = 17 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Wesal', wins = 4, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Other Aggro', deck = 'GW' WHERE finish = 18 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Dazai', wins = 4, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'UB Sheo' WHERE finish = 19 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'WingedHussar', wins = 4, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'PitchVine' WHERE finish = 20 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'OKMV', wins = 4, losses = 3, byes = 0, arch = 'DRS', subarch = '4c DRS Walkers', deck = 'nan' WHERE finish = 21 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'John1111', wins = 4, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'nan' WHERE finish = 22 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Oosunq', wins = 4, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'PitchVine' WHERE finish = 23 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'therealkinda', wins = 4, losses = 3, byes = 0, arch = 'Other', subarch = 'Other', deck = 'Jund Hermit' WHERE finish = 24 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'ecobaronen', wins = 4, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative' WHERE finish = 25 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Kinarus', wins = 4, losses = 3, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus Breach' WHERE finish = 26 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Cherryxman', wins = 4, losses = 3, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel' WHERE finish = 27 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'hockeybro26', wins = 3, losses = 4, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'PitchVine' WHERE finish = 28 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'D00mwake', wins = 3, losses = 4, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative' WHERE finish = 29 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Solidsnake408', wins = 3, losses = 4, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'nan' WHERE finish = 30 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'arrias', wins = 3, losses = 4, byes = 1, arch = 'Aggro', subarch = 'Other Blue Tempo', deck = 'BirdBlade' WHERE finish = 31 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Renerandrup', wins = 3, losses = 4, byes = 0, arch = 'Blue Tinker', subarch = 'Grixis Saga', deck = 'nan' WHERE finish = 32 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'dancingjesus191', wins = 3, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'UB Sheo' WHERE finish = 33 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'quinniac', wins = 3, losses = 4, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative' WHERE finish = 34 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'PsiVen', wins = 3, losses = 4, byes = 0, arch = 'Oath', subarch = 'Oath', deck = 'nan' WHERE finish = 35 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'HanktheObese', wins = 3, losses = 4, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 36 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Call1Me1Dragon', wins = 3, losses = 4, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'PitchVine' WHERE finish = 37 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'IamActuallyLvL1', wins = 3, losses = 4, byes = 0, arch = 'Oath', subarch = 'Oath', deck = 'Bant' WHERE finish = 38 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'swiftwarkite2', wins = 3, losses = 4, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'PitchVine' WHERE finish = 39 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'non_basic_land', wins = 2, losses = 3, byes = 1, arch = 'Shops', subarch = 'Aggro Shops', deck = 'nan' WHERE finish = 40 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Crazydiamond513', wins = 2, losses = 4, byes = 0, arch = 'Aggro', subarch = 'Other Blue Tempo', deck = 'Birdblade' WHERE finish = 41 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Gerschi', wins = 2, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'UB Sheo' WHERE finish = 42 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'bless_von', wins = 2, losses = 3, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 43 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'demonictutors', wins = 2, losses = 5, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 44 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'anexaltedpariah', wins = 2, losses = 5, byes = 1, arch = 'Combo', subarch = 'Breach', deck = 'nan' WHERE finish = 45 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'adm29', wins = 2, losses = 5, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative' WHERE finish = 46 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'NathanLipetz', wins = 1, losses = 1, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'nan' WHERE finish = 47 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'jewdan', wins = 1, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'nan' WHERE finish = 48 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Achillies27', wins = 1, losses = 3, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'Tinker' WHERE finish = 49 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'ForsakenBalerion', wins = 1, losses = 3, byes = 0, arch = 'Shops', subarch = 'Prison Shops', deck = 'nan' WHERE finish = 50 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'stu909090', wins = 1, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 51 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'thepowernine', wins = 1, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'UB Sheo' WHERE finish = 52 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Montolio', wins = 1, losses = 3, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'nan' WHERE finish = 53 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'discoverN', wins = 1, losses = 2, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'Tinker' WHERE finish = 54 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'KingHairy', wins = 1, losses = 2, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'Tinker' WHERE finish = 55 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'GigiOnAir', wins = 1, losses = 6, byes = 0, arch = 'Blue Tinker', subarch = 'Other Tinker', deck = 'UB Sheo' WHERE finish = 56 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'mogged', wins = 1, losses = 4, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'nan' WHERE finish = 57 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'ChainsOfMephistopPlz', wins = 0, losses = 2, byes = 0, arch = 'Oath', subarch = 'Oath', deck = 'RUG Control Oath' WHERE finish = 58 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'albertoSD', wins = 0, losses = 1, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative' WHERE finish = 59 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'sandydogmtg', wins = 0, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative' WHERE finish = 60 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'HeyNongMan', wins = 0, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative' WHERE finish = 61 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = '_Milhouse', wins = 0, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'PitchVine' WHERE finish = 62 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'LuisMJ', wins = 0, losses = 2, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'Tinker' WHERE finish = 63 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'xfile', wins = 0, losses = 2, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Storm' WHERE finish = 64 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'Cftsoc3', wins = 0, losses = 2, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel' WHERE finish = 65 AND event_id = '2022-12-17-Challenge-1'
# UPDATE vintage_results SET player = 'kasa', wins = 7, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Jeskai Lurrus' WHERE finish = 1 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'ZYURYO', wins = 6, losses = 3, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Jeskai No Lurrus' WHERE finish = 2 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'desolutionist', wins = 6, losses = 2, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Voidwalker Tendrils' WHERE finish = 3 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'Breckoroni', wins = 5, losses = 3, byes = 0, arch = 'Shops', subarch = 'Prison Shops', deck = 'Golos Shops' WHERE finish = 4 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'HanktheObese', wins = 6, losses = 1, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative Stompy' WHERE finish = 5 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'Shatun', wins = 5, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Jeskai Lurrus' WHERE finish = 6 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'Cherryxman', wins = 5, losses = 2, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel Shops' WHERE finish = 7 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'yeldarbflactem', wins = 5, losses = 2, byes = 0, arch = 'DRS', subarch = 'BUG', deck = 'BUG Lurrus' WHERE finish = 8 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'Mogged', wins = 4, losses = 2, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'Patchwork' WHERE finish = 9 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'albertoSD', wins = 4, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Initiative Stompy' WHERE finish = 10 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'shir kahn', wins = 4, losses = 2, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'Grixis Breach' WHERE finish = 11 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = '416FrowningTable', wins = 4, losses = 2, byes = 0, arch = 'Shops', subarch = 'Prison Shops', deck = 'Golos Shops' WHERE finish = 12 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'yPrincipe', wins = 4, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'White Hatebears' WHERE finish = 13 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'brianpk80', wins = 4, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Other Blue Tempo', deck = 'Esper Lurrus' WHERE finish = 14 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'Condescend', wins = 4, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Jeskai Lurrus' WHERE finish = 15 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'mosh110', wins = 4, losses = 2, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'Grixis Breach' WHERE finish = 16 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'revenantkioku', wins = 4, losses = 2, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'Doomsday' WHERE finish = 17 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'ice_nine_BIGFAN', wins = 3, losses = 3, byes = 0, arch = 'Shops', subarch = 'Combo Shops', deck = 'Jewel Shops' WHERE finish = 18 AND event_id = '2022-12-04-Challenge-1'
# UPDATE vintage_results SET player = 'burrarun', wins = 3, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'Esper PO' WHERE finish = 19 AND event_id = '2022-12-04-Challenge-1'
# ...
# UPDATE vintage_results SET player = 'grumgrum', wins = 1, losses = 5, byes = 0, arch = 'Oath', subarch = 'Oath', deck = 'Miharu Oath' WHERE finish = 41 AND event_id = '2022-09-04-Challenge-1'
# UPDATE vintage_results SET player = 'adm29', wins = 1, losses = 4, byes = 0, arch = 'Combo', subarch = 'Other Combo', deck = 'Welder Charbelcher' WHERE finish = 42 AND event_id = '2022-09-04-Challenge-1'
# UPDATE vintage_results SET player = 'Clamavus', wins = 1, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'UW PO' WHERE finish = 43 AND event_id = '2022-09-04-Challenge-1'
# UPDATE vintage_results SET player = 'burrarun', wins = 0, losses = 2, byes = 0, arch = 'DRS', subarch = 'BUG', deck = 'BUG' WHERE finish = 44 AND event_id = '2022-09-04-Challenge-1'
# UPDATE vintage_results SET player = 'TeamLeaderNa', wins = 0, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Dredge', deck = 'Dredge' WHERE finish = 45 AND event_id = '2022-09-04-Challenge-1'
# UPDATE vintage_results SET player = 'jez_organix', wins = 0, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'Aggro Bazaar' WHERE finish = 46 AND event_id = '2022-09-04-Challenge-1'
# UPDATE vintage_results SET player = 'LeoFa', wins = 0, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Grixis Saga', deck = 'Grixis Tinker' WHERE finish = 47 AND event_id = '2022-09-04-Challenge-1'
# UPDATE vintage_results SET player = 'scalo94', wins = 0, losses = 2, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'Aggro Shops' WHERE finish = 48 AND event_id = '2022-09-04-Challenge-1'
# UPDATE vintage_results SET player = 'Tsubasa_Cat', wins = 0, losses = 2, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 49 AND event_id = '2022-09-04-Challenge-1'
# UPDATE vintage_results SET player = 'HouseOfManaMTG', wins = 0, losses = 2, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'DD' WHERE finish = 50 AND event_id = '2022-09-04-Challenge-1'
# UPDATE vintage_results SET player = 'Lord_Beerus', wins = 8, losses = 0, byes = 0, arch = 'Bazaar', subarch = 'Dredge', deck = 'nan' WHERE finish = 1 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'handsomePPZ', wins = 7, losses = 1, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'nan' WHERE finish = 2 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'jankyb', wins = 6, losses = 2, byes = 0, arch = 'DRS', subarch = 'BUG', deck = 'nan' WHERE finish = 3 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Cover85', wins = 6, losses = 2, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'nan' WHERE finish = 4 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'RespectTheCat', wins = 5, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'Grixis PO' WHERE finish = 5 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Condescend', wins = 5, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'Esper Tinker' WHERE finish = 6 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'V4nquish', wins = 4, losses = 3, byes = 0, arch = 'Shops', subarch = 'Prison Shops', deck = 'nan' WHERE finish = 7 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Grymn', wins = 4, losses = 3, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'Lurrus' WHERE finish = 8 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Nooxtom', wins = 4, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'Lurrus' WHERE finish = 9 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'mammonth', wins = 4, losses = 2, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'nan' WHERE finish = 10 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'John1111', wins = 4, losses = 2, byes = 0, arch = 'DRS', subarch = 'BUG', deck = 'nan' WHERE finish = 11 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'otakkun', wins = 4, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'Esper Tinker' WHERE finish = 12 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'mogged', wins = 4, losses = 2, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'nan' WHERE finish = 13 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'S_P_O', wins = 4, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'nan' WHERE finish = 14 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'GGoggles', wins = 4, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'Grixis Saga', deck = 'Grixis Tinker' WHERE finish = 15 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Sti', wins = 4, losses = 2, byes = 0, arch = 'Combo', subarch = 'Oops All Spells', deck = 'nan' WHERE finish = 16 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'GontiLordofStuff', wins = 4, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'nan' WHERE finish = 17 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'matttothec', wins = 4, losses = 2, byes = 0, arch = 'Bazaar', subarch = 'Dredge', deck = 'nan' WHERE finish = 18 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Solidsnake408', wins = 4, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Mono White', deck = 'nan' WHERE finish = 19 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'yPrincipe', wins = 4, losses = 2, byes = 0, arch = 'Shops', subarch = 'Prison Shops', deck = 'nan' WHERE finish = 20 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'bless_von', wins = 3, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'Esper' WHERE finish = 21 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = '_Shatun_', wins = 3, losses = 3, byes = 0, arch = 'DRS', subarch = '4c DRS Walkers', deck = 'nan' WHERE finish = 22 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'thepowernine', wins = 3, losses = 3, byes = 0, arch = 'DRS', subarch = 'BUG', deck = 'nan' WHERE finish = 23 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'jben', wins = 3, losses = 3, byes = 1, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'nan' WHERE finish = 24 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Butakov', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'nan' WHERE finish = 25 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'moon11', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'nan' WHERE finish = 26 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'T1_Tinker', wins = 3, losses = 3, byes = 0, arch = 'DRS', subarch = 'BUG', deck = 'nan' WHERE finish = 27 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Oderus Urungus', wins = 3, losses = 3, byes = 0, arch = 'Shops', subarch = 'Prison Shops', deck = 'nan' WHERE finish = 28 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'simmsey', wins = 3, losses = 3, byes = 0, arch = 'DRS', subarch = 'BUG', deck = 'nan' WHERE finish = 29 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'thedeck84', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'nan' WHERE finish = 30 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Diem4x', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'nan' WHERE finish = 31 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Heibing', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'nan' WHERE finish = 32 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Sarlanga', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'nan' WHERE finish = 33 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Hitogoroshi80', wins = 3, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'nan' WHERE finish = 34 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Cherryxman', wins = 3, losses = 3, byes = 0, arch = 'Combo', subarch = 'Oops All Spells', deck = 'nan' WHERE finish = 35 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Oosunq', wins = 2, losses = 4, byes = 0, arch = 'Bazaar', subarch = 'Aggro Bazaar', deck = 'nan' WHERE finish = 36 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Latke', wins = 2, losses = 3, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'nan' WHERE finish = 37 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Avaloon', wins = 2, losses = 3, byes = 0, arch = 'Other', subarch = 'Other', deck = 'Goblins' WHERE finish = 38 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'hktknbr', wins = 2, losses = 4, byes = 1, arch = 'Combo', subarch = 'Other Combo', deck = 'nan' WHERE finish = 39 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'kanister', wins = 2, losses = 3, byes = 0, arch = 'Combo', subarch = 'Doomsday', deck = 'nan' WHERE finish = 40 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'IamActuallyLvL1', wins = 2, losses = 4, byes = 0, arch = 'Other', subarch = 'Other', deck = 'Helm Tinker' WHERE finish = 41 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Alico', wins = 2, losses = 4, byes = 0, arch = 'Bazaar', subarch = 'Dredge', deck = 'nan' WHERE finish = 42 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'desolutionist', wins = 2, losses = 3, byes = 0, arch = 'Blue Tinker', subarch = 'Grixis Saga', deck = 'Grixis' WHERE finish = 43 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Thalai', wins = 2, losses = 4, byes = 0, arch = 'DRS', subarch = 'BUG', deck = 'nan' WHERE finish = 44 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'laughingrock', wins = 2, losses = 4, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'nan' WHERE finish = 45 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'nietzreznor', wins = 2, losses = 4, byes = 0, arch = 'Shops', subarch = 'Aggro Shops', deck = 'nan' WHERE finish = 46 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Isv', wins = 1, losses = 2, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'nan' WHERE finish = 47 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'adm29', wins = 1, losses = 4, byes = 0, arch = 'Shops', subarch = 'Prison Shops', deck = 'nan' WHERE finish = 48 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Breckoroni', wins = 1, losses = 4, byes = 0, arch = 'Bazaar', subarch = 'Control Bazaar', deck = 'nan' WHERE finish = 49 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'medvedev', wins = 1, losses = 4, byes = 0, arch = 'Combo', subarch = 'Oops All Spells', deck = 'nan' WHERE finish = 50 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'parkss', wins = 1, losses = 2, byes = 0, arch = 'Oath', subarch = 'Oath', deck = 'nan' WHERE finish = 51 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'Hoey07', wins = 1, losses = 3, byes = 0, arch = 'Combo', subarch = 'Breach', deck = 'nan' WHERE finish = 52 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'boytriton', wins = 1, losses = 5, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'nan' WHERE finish = 53 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'ZYURYO', wins = 0, losses = 2, byes = 0, arch = 'Blue Control', subarch = 'Jeskai', deck = 'nan' WHERE finish = 54 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'KingHairy', wins = 0, losses = 1, byes = 0, arch = 'Blue Tinker', subarch = 'Esper Saga', deck = 'Esper' WHERE finish = 55 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'HouseOfManaMTG', wins = 0, losses = 2, byes = 0, arch = 'Blue Tinker', subarch = 'PO', deck = 'nan' WHERE finish = 56 AND event_id = '2022-09-03-Challenge-1'
# UPDATE vintage_results SET player = 'notmi', wins = 0, losses = 2, byes = 0, arch = 'Aggro', subarch = 'Other Blue Tempo', deck = 'Merfolk' WHERE finish = 57 AND event_id = '2022-09-03-Challenge-1'
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# c:\Users\chris\Documents\GitHub\Jupyter-Notebooks\2022-12-30-mtgo-vintage-metagame-etl-ms-azure.ipynb Cell 6 in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Documents/GitHub/Jupyter-Notebooks/2022-12-30-mtgo-vintage-metagame-etl-ms-azure.ipynb#W6sZmlsZQ%3D%3D?line=38'>39</a> try:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/chris/Documents/GitHub/Jupyter-Notebooks/2022-12-30-mtgo-vintage-metagame-etl-ms-azure.ipynb#W6sZmlsZQ%3D%3D?line=39'>40</a>     cursor.execute('INSERT INTO vintage_results (finish, player, wins, losses, byes, arch, subarch, deck, event_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)', values)
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Documents/GitHub/Jupyter-Notebooks/2022-12-30-mtgo-vintage-metagame-etl-ms-azure.ipynb#W6sZmlsZQ%3D%3D?line=40'>41</a>     results_added += 1
#
# IntegrityError: ('23000', "[23000] [Microsoft][ODBC SQL Server Driver][SQL Server]Violation of PRIMARY KEY constraint 'PK__vintage___74603C1A3F66BE01'. Cannot insert duplicate key in object 'dbo.vintage_results'. The duplicate key value is (2022-09-03-Challenge-1, 57). (2627) (SQLExecDirectW); [23000] [Microsoft][ODBC SQL Server Driver][SQL Server]The statement has been terminated. (3621)")
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\chris\Documents\GitHub\Jupyter-Notebooks\2022-12-30-mtgo-vintage-metagame-etl-ms-azure.ipynb Cell 6 in <module>
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Documents/GitHub/Jupyter-Notebooks/2022-12-30-mtgo-vintage-metagame-etl-ms-azure.ipynb#W6sZmlsZQ%3D%3D?line=42'>43</a>         sql = f"UPDATE vintage_results SET player = '{player}', wins = {wins}, losses = {losses}, byes = {byes}, arch = '{arch}', subarch = '{subarch}', deck = '{deck}' WHERE finish = {finish} AND event_id = '{event_id}'"
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Documents/GitHub/Jupyter-Notebooks/2022-12-30-mtgo-vintage-metagame-etl-ms-azure.ipynb#W6sZmlsZQ%3D%3D?line=43'>44</a>         print(sql)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/chris/Documents/GitHub/Jupyter-Notebooks/2022-12-30-mtgo-vintage-metagame-etl-ms-azure.ipynb#W6sZmlsZQ%3D%3D?line=44'>45</a>         cursor.execute(sql)
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Documents/GitHub/Jupyter-Notebooks/2022-12-30-mtgo-vintage-metagame-etl-ms-azure.ipynb#W6sZmlsZQ%3D%3D?line=45'>46</a>         results_updated += 1
#      <a href='vscode-notebook-cell:/c%3A/Users/chris/Documents/GitHub/Jupyter-Notebooks/2022-12-30-mtgo-vintage-metagame-etl-ms-azure.ipynb#W6sZmlsZQ%3D%3D?line=47'>48</a> print(f'events added: {events_added}, skipped: {events_updated}')
#
# KeyboardInterrupt:
